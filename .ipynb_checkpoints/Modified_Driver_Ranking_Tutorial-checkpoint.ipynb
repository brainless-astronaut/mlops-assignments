# %% [markdown]
# ### Overview
# Making a prediction using a linear regression model is a common use case in ML. In this guide tutorial, we build the model that predicts if a driver will complete a trip based on a number of features ingested into Feast.
#
# The basic local mode gives you ability to quickly try Feast, while the advanced mode shows how you can use Feast in a production setting, in particular for the Google Cloud Platform (GCP) cloud.
#
# This tutorial uses Feast with scikit learn to:
#
# * Train a model locally using data from BigQuery
# * Test the model for online inference using SQLite (for fast iteration)
# * Test the model for online inference using Firestore (to represent production)

# %% [markdown]
# ## Step 1: Install feast, scikit-learn
#
# Install feast, gcp dependencies and scikit-learn

# %%
# !pip install feast scikit-learn 'feast[gcp]'
# Out:
# Requirement already satisfied: feast in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (0.54.0)
# Requirement already satisfied: scikit-learn in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (8.3.0)
# Requirement already satisfied: colorama<1,>=0.3.9 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (0.4.6)
# Requirement already satisfied: dill~=0.3.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (0.3.9)
# Requirement already satisfied: protobuf>=4.24.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (6.32.1)
# Requirement already satisfied: Jinja2<4,>=2 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (3.1.6)
# Requirement already satisfied: jsonschema in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (4.25.1)
# Requirement already satisfied: mmh3 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (5.2.0)
# Requirement already satisfied: numpy<3,>=2.0.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.3.3)
# Requirement already satisfied: pandas<3,>=1.4.3 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.3.3)
# Requirement already satisfied: pyarrow<=17.0.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (17.0.0)
# Requirement already satisfied: pydantic==2.10.6 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.10.6)
# Requirement already satisfied: pygments<3,>=2.12.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.19.2)
# Requirement already satisfied: PyYAML<7,>=5.4.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (6.0.3)
# Requirement already satisfied: requests in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.32.5)
# Requirement already satisfied: SQLAlchemy[mypy]>1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.0.44)
# Requirement already satisfied: tabulate<1,>=0.8.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (0.9.0)
# Requirement already satisfied: tenacity<9,>=7 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (8.5.0)
# Requirement already satisfied: toml<1,>=0.10.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (0.10.2)
# Requirement already satisfied: tqdm<5,>=4 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (4.67.1)
# Requirement already satisfied: typeguard>=4.0.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (4.4.4)
# Requirement already satisfied: fastapi>=0.68.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (0.119.0)
# Requirement already satisfied: uvicorn[standard]<=0.34.0,>=0.30.6 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (0.34.0)
# Requirement already satisfied: uvicorn-worker in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (0.3.0)
# Requirement already satisfied: gunicorn in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (23.0.0)
# Requirement already satisfied: dask[dataframe]>=2024.2.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2025.9.1)
# Requirement already satisfied: prometheus_client in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (0.23.1)
# Requirement already satisfied: psutil in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (7.1.0)
# Requirement already satisfied: bigtree>=0.19.2 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (1.0.0)
# Requirement already satisfied: pyjwt in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.10.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pydantic==2.10.6->feast) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pydantic==2.10.6->feast) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pydantic==2.10.6->feast) (4.15.0)
# Requirement already satisfied: scipy>=1.8.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: google-api-core<3,>=1.23.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.26.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (1.70.0)
# Requirement already satisfied: google-cloud-bigquery[pandas]<4,>=2 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (3.38.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.0.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.33.1)
# Requirement already satisfied: google-cloud-datastore<3,>=2.16.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.21.0)
# Requirement already satisfied: google-cloud-storage<3,>=1.34.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.19.0)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.11.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2.33.0)
# Requirement already satisfied: fsspec<=2024.9.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from feast) (2024.9.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from dask[dataframe]>=2024.2.1->feast) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from dask[dataframe]>=2024.2.1->feast) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from dask[dataframe]>=2024.2.1->feast) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from dask[dataframe]>=2024.2.1->feast) (1.0.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from dask[dataframe]>=2024.2.1->feast) (8.7.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from fastapi>=0.68.0->feast) (0.48.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-api-core<3,>=1.23.0->feast) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-api-core<3,>=1.23.0->feast) (2.41.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-cloud-bigquery[pandas]<4,>=2->feast) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-cloud-bigquery[pandas]<4,>=2->feast) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-cloud-bigquery[pandas]<4,>=2->feast) (2.9.0.post0)
# Requirement already satisfied: pandas-gbq>=0.26.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-cloud-bigquery[pandas]<4,>=2->feast) (0.29.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.47.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-cloud-bigquery[pandas]<4,>=2->feast) (1.75.1)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-cloud-bigquery[pandas]<4,>=2->feast) (1.4.3)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-cloud-bigtable<3,>=2.11.0->feast) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-cloud-bigtable<3,>=2.11.0->feast) (1.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from Jinja2<4,>=2->feast) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pandas<3,>=1.4.3->feast) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pandas<3,>=1.4.3->feast) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from requests->feast) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from requests->feast) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from requests->feast) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from requests->feast) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from SQLAlchemy[mypy]>1->feast) (3.2.4)
# Requirement already satisfied: mypy>=0.910 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from SQLAlchemy[mypy]>1->feast) (1.18.2)
# Requirement already satisfied: h11>=0.8 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from uvicorn[standard]<=0.34.0,>=0.30.6->feast) (0.16.0)
# Requirement already satisfied: httptools>=0.6.3 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from uvicorn[standard]<=0.34.0,>=0.30.6->feast) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from uvicorn[standard]<=0.34.0,>=0.30.6->feast) (1.1.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from uvicorn[standard]<=0.34.0,>=0.30.6->feast) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from uvicorn[standard]<=0.34.0,>=0.30.6->feast) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from uvicorn[standard]<=0.34.0,>=0.30.6->feast) (15.0.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from jsonschema->feast) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from jsonschema->feast) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from jsonschema->feast) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from jsonschema->feast) (0.27.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-api-core<3,>=1.23.0->feast) (1.75.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3,>=1.23.0->feast) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3,>=1.23.0->feast) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3,>=1.23.0->feast) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask[dataframe]>=2024.2.1->feast) (3.23.0)
# Requirement already satisfied: mypy_extensions>=1.0.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from mypy>=0.910->SQLAlchemy[mypy]>1->feast) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from mypy>=0.910->SQLAlchemy[mypy]>1->feast) (0.12.1)
# Requirement already satisfied: setuptools in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pandas-gbq>=0.26.1->google-cloud-bigquery[pandas]<4,>=2->feast) (66.1.1)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pandas-gbq>=0.26.1->google-cloud-bigquery[pandas]<4,>=2->feast) (1.9.1)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pandas-gbq>=0.26.1->google-cloud-bigquery[pandas]<4,>=2->feast) (1.2.2)
# Requirement already satisfied: locket in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from partd>=1.4.0->dask[dataframe]>=2024.2.1->feast) (1.0.0)
# Requirement already satisfied: six>=1.5 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery[pandas]<4,>=2->feast) (1.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from starlette<0.49.0,>=0.40.0->fastapi>=0.68.0->feast) (4.11.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi>=0.68.0->feast) (1.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq>=0.26.1->google-cloud-bigquery[pandas]<4,>=2->feast) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3,>=1.23.0->feast) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq>=0.26.1->google-cloud-bigquery[pandas]<4,>=2->feast) (3.3.1)

# %% [markdown]
# #### Check feast version

# %%
# !feast version
# Out:
# Feast SDK Version: "0.54.0"

# %% [markdown]
# ## Step 2: Clone the Git repo
#
# Clone the Driver Ranking Git repo into your Colab Folder

# %%
# !git clone https://github.com/feast-dev/feast-driver-ranking-tutorial.git
# Out:
# fatal: destination path 'feast-driver-ranking-tutorial' already exists and is not an empty directory.

# %% [markdown]
# ## Step 3: Set up your Goggle Cloud Platform (GCP) Configurations

# %% [markdown]
# ## Authenticate into GCP
# This will allow you to do the advanced section of the tutorial, where you materialize remotely on a GCP
# Feast spins up infrastructure on GCP using the credentials in our environment. Run the following cell to log into GCP:

# %% [markdown]
# Set configurations
# Set the following configuration, which we'll be using throughout the tutorial:
#
# PROJECT_ID: Your project.
# BUCKET_NAME: The name of a bucket which will be used to store the feature store registry and model artifacts.
# BIGQUERY_DATASET_NAME: The name of a dataset which will be used to create tables containing features.
# AI_PLATFORM_MODEL_NAME: The name of a model name which will be created in AI Platform.

# %%
PROJECT_ID= "dulcet-bastion-452612-v4" #@param {type:"string"}
BUCKET_NAME= "dulcet-bastion-452612-v4-driver_ranking_tutorial" #@param {type:"string"} custom
BIGQUERY_DATASET_NAME="feast_driver_ranking_tutorial" #@param {type:"string"} custom
AI_PLATFORM_MODEL_NAME="feast_driver_rankin_jsd_model" #@param {type:"string"}

# Add the --quiet flag to automatically confirm
! gcloud config set project $PROJECT_ID --quiet
# %env GOOGLE_CLOUD_PROJECT=$PROJECT_ID
# !echo project_id = $PROJECT_ID > ~/.bigqueryrc
# Out:
# WARNING: [592784929565-compute@developer.gserviceaccount.com] does not have permission to access projects instance [dulcet-bastion-452612-v4] (or it may not exist): The caller does not have permission. This command is authenticated as 592784929565-compute@developer.gserviceaccount.com which is the active account specified by the [core/account] property
# Updated property [core/project].
# env: GOOGLE_CLOUD_PROJECT=dulcet-bastion-452612-v4

# %%
# Only run if your bucket doesn't already exist!
! gsutil mb gs://$BUCKET_NAME
# Out:
# Creating gs://dulcet-bastion-452612-v4-driver_ranking_tutorial/...
# AccessDeniedException: 403 592784929565-compute@developer.gserviceaccount.com does not have storage.buckets.create access to the Google Cloud project. Permission 'storage.buckets.create' denied on resource (or it may not exist).

# %% [markdown]
# ## Step 4: Apply and deploy feature definitions
#
# `feast apply` scans python files in the current directory for feature definitions and deploys infrastructure according to `feature_store.yaml`

# %%
# !cd feast-driver-ranking-tutorial/driver_ranking && feast apply
# Out:
# No project found in the repository. Using project name driver_ranking defined in feature_store.yaml
# Applying changes for project driver_ranking
# Traceback (most recent call last):
#   File "/home/ssahana1608/feast-venv/bin/feast", line 8, in <module>
#     sys.exit(cli())
#              ^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/click/core.py", line 1462, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/click/core.py", line 1383, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/click/core.py", line 1850, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/click/core.py", line 1246, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/click/core.py", line 814, in invoke
#     return callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/click/decorators.py", line 34, in new_func
#     return f(get_current_context(), *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/feast/cli/cli.py", line 272, in apply_total_command
#     apply_total(repo_config, repo, skip_source_validation)
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/feast/repo_operations.py", line 413, in apply_total
#     apply_total_with_repo_instance(
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/feast/repo_operations.py", line 360, in apply_total_with_repo_instance
#     store.apply(all_to_apply, objects_to_delete=all_to_delete, partial=False)
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/feast/feature_store.py", line 958, in apply
#     self._make_inferences(
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/feast/feature_store.py", line 606, in _make_inferences
#     update_data_sources_with_inferred_event_timestamp_col(
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/feast/inference.py", line 79, in update_data_sources_with_inferred_event_timestamp_col
#     ) in data_source.get_table_column_names_and_types(config):
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/feast/infra/offline_stores/file_source.py", line 189, in get_table_column_names_and_types
#     schema = ParquetDataset(path, **kwargs).schema
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/pyarrow/parquet/core.py", line 1371, in __init__
#     self._dataset = ds.dataset(path_or_paths, filesystem=filesystem,
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/pyarrow/dataset.py", line 794, in dataset
#     return _filesystem_dataset(source, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/pyarrow/dataset.py", line 476, in _filesystem_dataset
#     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ssahana1608/feast-venv/lib/python3.11/site-packages/pyarrow/dataset.py", line 441, in _ensure_single_source
#     raise FileNotFoundError(path)
# FileNotFoundError: /home/ssahana1608/ga_resources/feast-driver-ranking-tutorial/driver_ranking/../data/driver_stats.parquet

# %% [markdown]
# ### Inspect the files created under your local folder

# %%
# !cd /content/feast-driver-ranking-tutorial/driver_ranking/data/
# !ls -l
# Out:
# /bin/bash: line 1: cd: /content/feast-driver-ranking-tutorial/driver_ranking/data/: No such file or directory
# total 52
# -rw-r--r-- 1 ssahana1608 ssahana1608 34690 Oct 18 15:55 Modified_Driver_Ranking_Tutorial.ipynb
# -rw-r--r-- 1 ssahana1608 ssahana1608  4298 Oct 12 15:08 README.md
# drwxr-xr-x 5 ssahana1608 ssahana1608  4096 Oct 12 15:48 feast-driver-ranking-tutorial
# -rw-r--r-- 1 ssahana1608 ssahana1608  4009 Oct 12 15:08 iris_data_adapted_for_feast.csv

# %% [markdown]
# ## Step 5: Train your model

# %%
# !pip install "numpy<2" "pandas==2.2.2"
# Out:
# Collecting numpy<2
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 33.9 MB/s eta 0:00:0000:0100:01
# Collecting pandas==2.2.2
#   Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 38.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/ssahana1608/feast-venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Installing collected packages: numpy, pandas
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:
#       Successfully uninstalled numpy-2.3.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.3
#     Uninstalling pandas-2.3.3:
#       Successfully uninstalled pandas-2.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# feast 0.54.0 requires numpy<3,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4 pandas-2.2.2

# %%
import feast
from joblib import dump
import pandas as pd
from sklearn.linear_model import LinearRegression

# Load driver order data
orders = pd.read_csv("/content/feast-driver-ranking-tutorial/driver_orders.csv", sep="\t")
orders["event_timestamp"] = pd.to_datetime(orders["event_timestamp"])

# Connect to your feature store provider
fs = feast.FeatureStore(repo_path="/content/feast-driver-ranking-tutorial/driver_ranking")

# Retrieve training data from BigQuery
training_df = fs.get_historical_features(
    entity_df=orders,
    features=[
        "driver_hourly_stats:conv_rate",
        "driver_hourly_stats:acc_rate",
        "driver_hourly_stats:avg_daily_trips",
    ],
).to_df()

print("----- Feature schema -----\n")
print(training_df.info())

print()
print("----- Example features -----\n")
print(training_df.head())

# Train model
target = "trip_completed"

reg = LinearRegression()
train_X = training_df[training_df.columns.drop(target).drop("event_timestamp")]
train_Y = training_df.loc[:, target]
reg.fit(train_X[sorted(train_X)], train_Y)

# Save model
dump(reg, "driver_model.bin")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 7
#       4 from sklearn.linear_model import LinearRegression
#       6 # Load driver order data
# ----> 7 orders = pd.read_csv("/content/feast-driver-ranking-tutorial/driver_orders.csv", sep="\t")
#       8 orders["event_timestamp"] = pd.to_datetime(orders["event_timestamp"])
#      10 # Connect to your feature store provider
#
# File ~/feast-venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/feast-venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/feast-venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/feast-venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/feast-venv/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/feast-driver-ranking-tutorial/driver_orders.csv'

# %% [markdown]
# ## Step 6: Materialize your online store
# Apply and materialize data to Firestore

# %%
# !cd /content/feast-driver-ranking-tutorial/driver_ranking/ && feast materialize 2021-01-01T00:00:00 2022-01-01T00:00:00
# Out:
# /bin/bash: line 1: cd: /content/feast-driver-ranking-tutorial/driver_ranking/: No such file or directory

# %% [markdown]
# ### Step 7:  Make Prediction

# %%
import pandas as pd
import feast
from joblib import load


class DriverRankingModel:
    def __init__(self):
        # Load model
        self.model = load("/content/driver_model.bin")

        # Set up feature store
        self.fs = feast.FeatureStore(repo_path="/content/feast-driver-ranking-tutorial/driver_ranking/")

    def predict(self, driver_ids):
        # Read features from Feast
        driver_features = self.fs.get_online_features(
            entity_rows=[{"driver_id": driver_id} for driver_id in driver_ids],
            features=[
                "driver_hourly_stats:conv_rate",
                "driver_hourly_stats:acc_rate",
                "driver_hourly_stats:avg_daily_trips",
            ],
        )
        df = pd.DataFrame.from_dict(driver_features.to_dict())

        # Make prediction
        df["prediction"] = self.model.predict(df[sorted(df)])

        # Choose best driver
        best_driver_id = df["driver_id"].iloc[df["prediction"].argmax()]

        # return best driver
        return best_driver_id

# %%
def make_drivers_prediction():
    drivers = [1001, 1002, 1003, 1004]
    model = DriverRankingModel()
    best_driver = model.predict(drivers)
    print(f"Prediction for best driver id: {best_driver}")

# %%
make_drivers_prediction()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 make_drivers_prediction()
#
# Cell In[12], line 3, in make_drivers_prediction()
#       1 def make_drivers_prediction():
#       2     drivers = [1001, 1002, 1003, 1004]
# ----> 3     model = DriverRankingModel()
#       4     best_driver = model.predict(drivers)
#       5     print(f"Prediction for best driver id: {best_driver}")
#
# Cell In[11], line 9, in DriverRankingModel.__init__(self)
#       7 def __init__(self):
#       8     # Load model
# ----> 9     self.model = load("/content/driver_model.bin")
#      11     # Set up feature store
#      12     self.fs = feast.FeatureStore(repo_path="/content/feast-driver-ranking-tutorial/driver_ranking/")
#
# File ~/feast-venv/lib/python3.11/site-packages/joblib/numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
#     742                 # try to load a pickle file generated with an version of
#     743                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/driver_model.bin'
